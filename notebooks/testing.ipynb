# %%
#IMPORTS
import sys
import os
import pandas as pd
#Fix Notebook Path
sys.path.append(os.path.abspath(".."))

from src.preprocessing_data.pre_processing import PreProcessor
from src.models.train_model import BasicLogisticRegressionTraining

# %%
#CONSTANTS
FILEPATH = "../src/data/raw/all_reviews.csv"
TRAIN_PATH = "../src/data/processed/train.csv"
TEST_PATH = "../src/data/processed/test.csv"

# %%
pd.set_option("display.max_columns", None)
FILEPATH = "../src/data/raw/all_reviews.csv"

nrows = 10000  #Number of rows limited to 100,000 to reduce run time
x = PreProcessor(FILEPATH)
df = x.load_data(nrows)
df.head()
# Out:
#    recommendationid  appid            game     author_steamid  \
# 0         148919893     10  Counter-Strike  76561199036724879
# 1         148919350     10  Counter-Strike  76561198826729322
# 2         148913051     10  Counter-Strike  76561199101237625
# 3         148912714     10  Counter-Strike  76561198347582422
# 4         148912575     10  Counter-Strike  76561198363716821
#
#    author_num_games_owned  author_num_reviews  author_playtime_forever  \
# 0                       0                   3                      197
# 1                       0                  21                      441
# 2                       7                   1                     1440
# 3                      11                   4                     1636
# 4                       0                   2                      197
#
#    author_playtime_last_two_weeks  author_playtime_at_review  \
# 0                             197                        197
# 1                              37                        441
# 2                            1440                       1313
# 3                              83                       1612
# 4                              41                        197
#
#    author_last_played language              review  timestamp_created  \
# 0          1698336369  russian            старость         1698336397
# 1          1698335809  russian          Лучше кс 2         1698335821
# 2          1698338635  turkish  çoh iyi ama pahalı         1698329862
# 3          1698341834  russian                 топ         1698329555
# 4          1698329401  english        GOAT Game !!         1698329419
#
#    timestamp_updated  voted_up  votes_up  votes_funny  weighted_vote_score  \
# 0         1698336397         1         0            0                  0.0
# 1         1698335821         1         0            0                  0.0
# 2         1698329862         1         0            0                  0.0
# 3         1698329555         1         0            0                  0.0
# 4         1698329419         1         0            0                  0.0
#
#    comment_count  steam_purchase  received_for_free  \
# 0              0               1                  0
# 1              0               1                  0
# 2              0               1                  0
# 3              0               1                  0
# 4              0               1                  0
#
#    written_during_early_access  hidden_in_steam_china  steam_china_location
# 0                            0                      1                   NaN
# 1                            0                      1                   NaN
# 2                            0                      1                   NaN
# 3                            0                      1                   NaN
# 4                            0                      1                   NaN

# %%
print((df["review"].str.strip() == "").sum())
print("________________________")
nan_count = df.isna().sum()
print(nan_count)
# Out:
# 6
# ________________________
# recommendationid                      0
# appid                                 0
# game                                  0
# author_steamid                        0
# author_num_games_owned                0
# author_num_reviews                    0
# author_playtime_forever               0
# author_playtime_last_two_weeks        0
# author_playtime_at_review             0
# author_last_played                    0
# language                              0
# review                                0
# timestamp_created                     0
# timestamp_updated                     0
# voted_up                              0
# votes_up                              0
# votes_funny                           0
# weighted_vote_score                   0
# comment_count                         0
# steam_purchase                        0
# received_for_free                     0
# written_during_early_access           0
# hidden_in_steam_china                 0
# steam_china_location              10000
# dtype: int64

# %%
df = x.preprocess(nrows)
df.head()
# Out:
#              game     author_steamid  author_num_games_owned  \
# 0  Counter-Strike  76561199036724879                       0
# 1  Counter-Strike  76561198826729322                       0
# 2  Counter-Strike  76561199101237625                       7
# 3  Counter-Strike  76561198347582422                      11
# 4  Counter-Strike  76561198363716821                       0
#
#    author_num_reviews  author_playtime_forever  \
# 0                   3                      197
# 1                  21                      441
# 2                   1                     1440
# 3                   4                     1636
# 4                   2                      197
#
#    author_playtime_last_two_weeks  author_playtime_at_review  \
# 0                             197                        197
# 1                              37                        441
# 2                            1440                       1313
# 3                              83                       1612
# 4                              41                        197
#
#    author_last_played language              review   timestamp_created  \
# 0 2023-10-26 16:06:09  russian            старость 2023-10-26 16:06:37
# 1 2023-10-26 15:56:49  russian          Лучше кс 2 2023-10-26 15:57:01
# 2 2023-10-26 16:43:55  turkish  çoh iyi ama pahalı 2023-10-26 14:17:42
# 3 2023-10-26 17:37:14  russian                 топ 2023-10-26 14:12:35
# 4 2023-10-26 14:10:01  english        GOAT Game !! 2023-10-26 14:10:19
#
#     timestamp_updated  voted_up  votes_up  votes_funny  weighted_vote_score  \
# 0 2023-10-26 16:06:37         1         0            0                  0.0
# 1 2023-10-26 15:57:01         1         0            0                  0.0
# 2 2023-10-26 14:17:42         1         0            0                  0.0
# 3 2023-10-26 14:12:35         1         0            0                  0.0
# 4 2023-10-26 14:10:19         1         0            0                  0.0
#
#    comment_count  steam_purchase  received_for_free  \
# 0              0               1                  0
# 1              0               1                  0
# 2              0               1                  0
# 3              0               1                  0
# 4              0               1                  0
#
#    written_during_early_access
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0

# %%
print((df["review"].str.strip() == "").sum())
print("________________________")
nan_count = df.isna().sum()
print(nan_count)
# Out:
# 0
# ________________________
# game                              0
# author_steamid                    0
# author_num_games_owned            0
# author_num_reviews                0
# author_playtime_forever           0
# author_playtime_last_two_weeks    0
# author_playtime_at_review         0
# author_last_played                0
# language                          0
# review                            0
# timestamp_created                 0
# timestamp_updated                 0
# voted_up                          0
# votes_up                          0
# votes_funny                       0
# weighted_vote_score               0
# comment_count                     0
# steam_purchase                    0
# received_for_free                 0
# written_during_early_access       0
# dtype: int64

# %%
lr = BasicLogisticRegressionTesting(TRAIN_PATH,TEST_PATH)
results = lr.run_lr_pipeline()
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 lr = BasicLogisticRegression(TRAIN_PATH,TEST_PATH)
#       2 results = lr.run_lr_pipeline()
#       3 print(results)
#
# NameError: name 'BasicLogisticRegression' is not defined
